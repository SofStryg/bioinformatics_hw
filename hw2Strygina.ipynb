# %% [markdown]
# #  Часть 1

# %% [markdown]
# ### Взяла белок Cytochrome из 4х разных биологических видов(последовательности лежат в файле proteins.txt)
#
# - Homo sapiens
# - Mus musculus
# - Rattus norvegicus
# - Macaca mulatta

# %% [markdown]
# ###
# Получила Newick формат выравнивания.
# При помощи сайта отстроила филогенетическое дерево по полученному Newick. (все лежит в папке part1_screens)

# %% [markdown]
# # Часть 2
#
# Взяла файлик, сделала выравнивание для последовательностей Sars-CoV2, затем построила дерево.
#
# И вот вывод:
#
# Филогенетический анализ показал гетерогенность выборки: два образца (4568 и 3849) демонстрируют уникальные паттерны в начале последовательности и локализуются на дереве на отдельных, удалённых ветвях, что указывает на их вероятное происхождение от других вариантов. Основная же часть образцов группируется в высоконадёжный кластер, что отражает их общее происхождение и принадлежность к одному распространённому штамму.

# %% [markdown]
# После добавления 3-х новых штаммов:
#
# Филогенетическое дерево демонстрирует объединение образцов из Бразилии, США и Таиланда в один высоконадёжный кластер с образцами 4568 и 3849 (бустреп = 90%). Поскольку образцы 4568 и 3849 уже на предыдущем этапе анализа проявляли отличия от доминирующего в РФ кластера, можно с высокой вероятностью заключить, что они представляют собой завозные варианты, генетически близкие к международным штаммам.

# %% [markdown]
# Все скрины лежат в папке part2_screens
